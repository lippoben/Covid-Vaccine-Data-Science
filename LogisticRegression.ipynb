# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Using TF-IDF on the cleaned tweets

# %%
df = pd.DataFrame()
df = pd.read_csv('Datasets/train_tweets_clean.csv', encoding = 'utf-8', usecols = ['SpellCheckTweets', 'Sentiment'])
df.head()
# Out:
#    Sentiment                                   SpellCheckTweets
# 0          1                           ll sown sure hayne chill
# 1          1  life eh hard good happy us may nagpapasaya na ...
# 2          1                  phrase rolling totally make sense
# 3          0  companion dragonlance meeting extent vol mass ...
# 4          0  word advanced window advanced short course sho...

# %%
df['SpellCheckTweets'] = df['SpellCheckTweets'].astype('str')

# %%
X = df['SpellCheckTweets']
y = df['Sentiment']


vectorizer = TfidfVectorizer()
tf_idf_X = vectorizer.fit_transform(X)
tf_idf_X
# Out:
# <199998x47617 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1336499 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Splitting the data with an 80:20 ratio

# %%
# We are performing a 80:20 split.

X_train1, X_test1, y_train1, y_test1 = train_test_split(tf_idf_X, y, random_state=200)

# %% [markdown]
# Fitting a logistic regression model to the transformed data.

# %%
lr = LogisticRegression(solver='saga')

# %%
lr.fit(X_train1, y_train1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='saga',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predicted_test = lr.predict(X_test1)
predicted_proba_test = lr.predict_proba(X_test1)

# %%
predicted_test = lr.predict(X_test1)

y_test = y_test.astype('category')
print(metrics.classification_report(y_test, predicted_test,
    labels=y_test.cat.categories.tolist()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78     24890
#            1       0.77      0.81      0.79     25110
#
#    micro avg       0.78      0.78      0.78     50000
#    macro avg       0.78      0.78      0.78     50000
# weighted avg       0.78      0.78      0.78     50000

# %% [markdown]
# This model has a precision of 0.80 for negative tweets and 0.77 for positive tweets.

# %%
ConMatTest = metrics.confusion_matrix(y_test1, predicted_test)
accuracy = lr.score(X_test1, y_test1)

print(ConMatTest)
print(f'Accuracy = {accuracy:.2f}')
# Out:
# [[18925  5965]
#  [ 4849 20261]]
# Accuracy = 0.78

# %% [markdown]
# This model has an accuracy of 78%

# %% [markdown]
# ## Validation Set

# %% [markdown]
# Splitting the data into training:testing sets with a ratio 80:20.
#
# Then, by splitting the training set, we will create a validation set, so that the overall ratio of train:validation:test is 60:20:20

# %%
# Splitting to create train and test sets
X_train, X_test, y_train, y_test = train_test_split(tf_idf_X, y, test_size=0.2, random_state=200)

# Splitting to create train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=200)

# %% [markdown]
# Comparing the different hyperparameters offered by sklearn's logistic regression model

# %%
lr = LogisticRegression(solver='saga')
lr.fit(X_train, y_train)
print('Accuracy: ' + str(lr.score(X_val,y_val)) + ' Solver: saga')
lr = LogisticRegression(solver='newton-cg')
lr.fit(X_train, y_train)
print('Accuracy: ' + str(lr.score(X_val,y_val)) + ' Solver: newton-cg')
lr = LogisticRegression(solver='lbfgs')
lr.fit(X_train, y_train)
print('Accuracy: ' + str(lr.score(X_val,y_val)) + ' Solver: lbfgs')
lr = LogisticRegression(solver='liblinear')
lr.fit(X_train, y_train)
print('Accuracy: ' + str(lr.score(X_val,y_val)) + ' Solver: liblinear')
lr = LogisticRegression(solver='sag')
lr.fit(X_train, y_train)
print('Accuracy: ' + str(lr.score(X_val,y_val)) + ' Solver: sag')
# Out:
# Accuracy: 0.815175 Solver: saga
# Accuracy: 0.815175 Solver: newton-cg
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Accuracy: 0.814875 Solver: lbfgs
# Accuracy: 0.815175 Solver: liblinear
# Accuracy: 0.815175 Solver: sag

# %% [markdown]
# Here we can see that all the 'solvers' perform equally as well (accuracy = 0.815175), except 'lbfgs' which has a slightly lower accuracy (0.814875).

# %% [markdown]
# Testing each combination of solver, penalty and C by using a gridsearch technique

# %%
from sklearn.model_selection import GridSearchCV

# %%
lr = LogisticRegression()
solvers = ['saga','newton-cg','lbfgs','liblinear','sag']
penalties = ['l1', 'l2', 'elasticnet', 'none']
C_values = [0.01,0.1,1,10,100]
grid = dict(solver=solvers, penalty=penalties, C=C_values)
grid_search = GridSearchCV(lr, grid, n_jobs=-1, scoring='accuracy', error_score=0)
grid_result = grid_search.fit(X_train1, y_train1)
# Out:
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
# ...
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))
# /Users/victoriaadcock/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/numpy_pickle.py:104: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   pickler.file_handle.write(chunk.tostring('C'))

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("{} ({}) with: {}".format(mean, stdev, param))
# Out:
# 0.6288750516673556 (0.0011276496629218367) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.6292550567340898 (0.0013584615751696205) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'sag'}
# 0.7212962839504526 (0.0010768313574108335) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}
# 0.7212696169282257 (0.0010676821474137374) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7212762836837825 (0.001049398947837482) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7215629541727223 (0.0011508988038740615) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7212829504393392 (0.0010585380992763512) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'elasticnet', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'none', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'none', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'none', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'none', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 0.01, 'penalty': 'none', 'solver': 'sag'}
# 0.7389765196869291 (0.0019855999417628086) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.7391031880425072 (0.0019480460243121041) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'sag'}
# 0.7629835064467526 (0.0012841373496192447) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}
# 0.7629968399578662 (0.0012819286978876091) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7630035067134229 (0.0013047147734293722) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7629968399578662 (0.0012887505981998538) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7630101734689796 (0.0012864116732616885) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'elasticnet', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'none', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'none', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'none', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'none', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 0.1, 'penalty': 'none', 'solver': 'sag'}
# 0.7784370458272777 (0.0006771564290585828) with: {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.7784437125828344 (0.0006762661901602256) with: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'l1', 'solver': 'sag'}
# 0.7811437485833145 (0.0006694837060548855) with: {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# 0.7811437485833145 (0.0006694837060548855) with: {'C': 1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7811370818277577 (0.0006121374323759137) with: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7811370818277577 (0.0006702280939187699) with: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7811437485833145 (0.0006694837060548855) with: {'C': 1, 'penalty': 'l2', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'elasticnet', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'none', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'none', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'none', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'none', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 1, 'penalty': 'none', 'solver': 'sag'}
# 0.7701836024480326 (0.00022824630247753058) with: {'C': 10, 'penalty': 'l1', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.7691635888478513 (0.0004985286632915245) with: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'l1', 'solver': 'sag'}
# 0.7748703316044214 (0.0006528890097111977) with: {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
# 0.7748436645821944 (0.0006405806578163139) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7736836491153215 (0.0005735500691606707) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7748303310710809 (0.000634547097041046) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7748369978266377 (0.0006313010198962239) with: {'C': 10, 'penalty': 'l2', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'elasticnet', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'none', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'none', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'none', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'none', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 10, 'penalty': 'none', 'solver': 'sag'}
# 0.7618834917798905 (0.0009270638224329251) with: {'C': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.7547900638675182 (0.00187287875144068) with: {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'l1', 'solver': 'sag'}
# 0.7629301724022987 (0.0008630586919049458) with: {'C': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.7621368284910466 (0.000875894964419743) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7659102121361618 (0.0009670242724199596) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7621368284910466 (0.000904651145694153) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7621034947132629 (0.0009509899678327048) with: {'C': 100, 'penalty': 'l2', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'elasticnet', 'solver': 'sag'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'none', 'solver': 'saga'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'none', 'solver': 'newton-cg'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'none', 'solver': 'lbfgs'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'none', 'solver': 'liblinear'}
# 0.0 (0.0) with: {'C': 100, 'penalty': 'none', 'solver': 'sag'}

# %%
print("Best combination: {} with accuracy of {}".format(grid_result.best_params_,grid_result.best_score_))
# Out:
# Best combination: {'C': 1, 'penalty': 'l2', 'solver': 'saga'} with accuracy of 0.7811437485833145
